# %%
#connect google dirve
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

path = '/content/drive/MyDrive/USC Coursework/Artificial Intelligence - CSCE 580/CSCE580-Fall2024-Nayeem-SharedInfo/DriverTraining-ForInClassLearning-2024.csv'
df = pd.read_csv(path)
df.head()
# Out:
#   class_date      city           state    zip_code       dob  gender
# 0    8/17/24  Richburg  South Carolina       29729  11/30/07    Male
# 1    8/10/24  Bluffton  South Carolina  29910-7957  10/16/07    Male
# 2    8/14/24   Hampton  South Carolina       29924    7/3/08  Female
# 3     8/9/24  Columbia  South Carolina       29210  10/10/06  Female
# 4    8/17/24      Irmo  South Carolina       29063  12/23/06  Female

# %%
import numpy as np
np.random.seed(31)
df['good_driver'] = np.random.choice([0, 1], size=len(df), p=[0.5, 0.5])
df.head()
# Out:
#   class_date      city           state    zip_code       dob  gender  \
# 0    8/17/24  Richburg  South Carolina       29729  11/30/07    Male
# 1    8/10/24  Bluffton  South Carolina  29910-7957  10/16/07    Male
# 2    8/14/24   Hampton  South Carolina       29924    7/3/08  Female
# 3     8/9/24  Columbia  South Carolina       29210  10/10/06  Female
# 4    8/17/24      Irmo  South Carolina       29063  12/23/06  Female
#
#    good_driver
# 0            0
# 1            1
# 2            1
# 3            1
# 4            0

# %%
print(len(df[df['good_driver'] == 1]))
print(len(df[df['good_driver'] == 0]))
print(len(df))
# Out:
# 8479
# 8421
# 16900

# %%
driving_df = df.dropna().reset_index(drop=True)

# %%
driving_df['dob'] = driving_df['dob'].astype(str)
driving_df[['month','day', 'year']] = driving_df['dob'].str.split('/', expand=True)

# %%
for col in ['month', 'day', 'year']:
  driving_df[col] = pd.to_numeric(driving_df[col], errors='coerce').fillna(0).astype(int)

# %%
driving_df['Class Date'] = pd.to_datetime(driving_df['class_date'], format='%m/%d/%y')
driving_df
# Out:
#       class_date             city           state    zip_code       dob  \
# 0        8/17/24         Richburg  South Carolina       29729  11/30/07
# 1        8/10/24         Bluffton  South Carolina  29910-7957  10/16/07
# 2        8/14/24          Hampton  South Carolina       29924    7/3/08
# 3         8/9/24         Columbia  South Carolina       29210  10/10/06
# 4        8/17/24             Irmo  South Carolina       29063  12/23/06
# ...          ...              ...             ...         ...       ...
# 16593    2/25/23          Chesnee  South Carolina       29323  11/16/05
# 16594     2/4/23       Greenville  South Carolina       29607   5/22/07
# 16595     2/4/23        Greenwood  South Carolina       29649   7/15/06
# 16596     2/8/23  Boiling Springs  South Carolina       29316   2/17/06
# 16597    2/18/23       Lake Wylie  South Carolina       29710   1/30/07
#
#        gender  good_driver  month  day  year Class Date
# ...

# %%
for i in range(len(driving_df)):
  if driving_df.at[i, 'year'] < 17 and driving_df.at[i, 'year'] >= 0:
    driving_df.at[i, 'year']+= 2000
  else:
    driving_df.at[i, 'year'] += 1900

# %%
driving_df['date_of_birth'] = pd.to_datetime(driving_df[['year', 'month', 'day']])
driving_df
# Out:
#       class_date             city           state    zip_code       dob  \
# 0        8/17/24         Richburg  South Carolina       29729  11/30/07
# 1        8/10/24         Bluffton  South Carolina  29910-7957  10/16/07
# 2        8/14/24          Hampton  South Carolina       29924    7/3/08
# 3         8/9/24         Columbia  South Carolina       29210  10/10/06
# 4        8/17/24             Irmo  South Carolina       29063  12/23/06
# ...          ...              ...             ...         ...       ...
# 16593    2/25/23          Chesnee  South Carolina       29323  11/16/05
# 16594     2/4/23       Greenville  South Carolina       29607   5/22/07
# 16595     2/4/23        Greenwood  South Carolina       29649   7/15/06
# 16596     2/8/23  Boiling Springs  South Carolina       29316   2/17/06
# 16597    2/18/23       Lake Wylie  South Carolina       29710   1/30/07
#
#        gender  good_driver  month  day  year Class Date date_of_birth
# ...

# %%
# Calculate age by subtracting birth year from class date year
driving_df['age'] = driving_df['Class Date'].dt.year - driving_df['date_of_birth'].dt.year

# Adjust the age if the class date has not yet passed the birthday for that year
driving_df['age'] = driving_df['age'] - (
    (driving_df['Class Date'].dt.month < driving_df['date_of_birth'].dt.month) |
    ((driving_df['Class Date'].dt.month == driving_df['date_of_birth'].dt.month) &
     (driving_df['Class Date'].dt.day < driving_df['date_of_birth'].dt.day))
)
driving_df
# Out:
#       class_date             city           state    zip_code       dob  \
# 0        8/17/24         Richburg  South Carolina       29729  11/30/07
# 1        8/10/24         Bluffton  South Carolina  29910-7957  10/16/07
# 2        8/14/24          Hampton  South Carolina       29924    7/3/08
# 3         8/9/24         Columbia  South Carolina       29210  10/10/06
# 4        8/17/24             Irmo  South Carolina       29063  12/23/06
# ...          ...              ...             ...         ...       ...
# 16593    2/25/23          Chesnee  South Carolina       29323  11/16/05
# 16594     2/4/23       Greenville  South Carolina       29607   5/22/07
# 16595     2/4/23        Greenwood  South Carolina       29649   7/15/06
# 16596     2/8/23  Boiling Springs  South Carolina       29316   2/17/06
# 16597    2/18/23       Lake Wylie  South Carolina       29710   1/30/07
#
#        gender  good_driver  month  day  year Class Date date_of_birth  age
# ...

# %%
display(driving_df)
# Out:
#       class_date             city           state    zip_code  gender  \
# 0        8/17/24         Richburg  South Carolina       29729    Male
# 1        8/10/24         Bluffton  South Carolina  29910-7957    Male
# 2        8/14/24          Hampton  South Carolina       29924  Female
# 3         8/9/24         Columbia  South Carolina       29210  Female
# 4        8/17/24             Irmo  South Carolina       29063  Female
# ...          ...              ...             ...         ...     ...
# 16593    2/25/23          Chesnee  South Carolina       29323  Female
# 16594     2/4/23       Greenville  South Carolina       29607    Male
# 16595     2/4/23        Greenwood  South Carolina       29649  Female
# 16596     2/8/23  Boiling Springs  South Carolina       29316    Male
# 16597    2/18/23       Lake Wylie  South Carolina       29710    Male
#
#        good_driver Class Date date_of_birth  age
# 0                0 2024-08-17    2007-11-30   16
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from datetime import datetime

# %%
df = driving_df.copy()
# Encode categorical variables
label_encoder = LabelEncoder()
df['city'] = label_encoder.fit_transform(df['city'])
df['state'] = label_encoder.fit_transform(df['state'])
df['gender'] = label_encoder.fit_transform(df['gender'])
df
# Out:
#       class_date  city  state    zip_code  gender  good_driver Class Date  \
# 0        8/17/24   364     11       29729       1            0 2024-08-17
# 1        8/10/24    34     11  29910-7957       1            1 2024-08-10
# 2        8/14/24   192     11       29924       0            1 2024-08-14
# 3         8/9/24    93     11       29210       0            1 2024-08-09
# 4        8/17/24   214     11       29063       0            0 2024-08-17
# ...          ...   ...    ...         ...     ...          ...        ...
# 16593    2/25/23    77     11       29323       0            0 2023-02-25
# 16594     2/4/23   184     11       29607       1            0 2023-02-04
# 16595     2/4/23   186     11       29649       0            1 2023-02-04
# 16596     2/8/23    41     11       29316       1            1 2023-02-08
# 16597    2/18/23   236     11       29710       1            0 2023-02-18
#
#       date_of_birth  age
# 0        2007-11-30   16
# 1        2007-10-16   16
# ...

# %%
df.columns
# Out:
# Index(['class_date', 'city', 'state', 'zip_code', 'gender', 'good_driver',
#        'Class Date', 'date_of_birth', 'age'],
#       dtype='object')

# %%
df['state'].unique()
# Out:
# array([11,  3,  4,  8,  7, 12,  1,  2,  9, 13, 14,  5, 10,  6,  0])

# %%
# Drop irrelevant or now-processed columns
df.drop(columns=['class_date', 'zip_code', 'Class Date', 'date_of_birth'], inplace=True)

# Define features and target variable
X = df.drop(columns=['good_driver'])
y = df['good_driver']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Model Training
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

# Model Prediction
y_pred = rf_model.predict(X_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(accuracy, ' ', classification_rep)
# Out:
# 0.5020080321285141                 precision    recall  f1-score   support
#
#            0       0.51      0.40      0.45      2510
#            1       0.50      0.61      0.55      2470
#
#     accuracy                           0.50      4980
#    macro avg       0.50      0.50      0.50      4980
# weighted avg       0.50      0.50      0.50      4980

# %%
X
# Out:
#        city  state  gender  age
# 0       364     11       1   16
# 1        34     11       1   16
# 2       192     11       0   16
# 3        93     11       0   17
# 4       214     11       0   17
# ...     ...    ...     ...  ...
# 16593    77     11       0   17
# 16594   184     11       1   15
# 16595   186     11       0   16
# 16596    41     11       1   16
# 16597   236     11       1   16
#
# [16598 rows x 4 columns]

# %%
# !pip install lime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=d24c314965ec951f9a00b407a2d9c77de6bc79266b1aeea6ff5587e86fe34bfd
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# ...

# %%
from lime.lime_tabular import LimeTabularExplainer

# %%
# Extract the first five rows from the data corresponding to the specified cities
first_five_rows = X[:5]

# Define the LIME explainer
explainer = LimeTabularExplainer(
    X_train.values,
    feature_names=X.columns,
    class_names=['not_good_driver', 'good_driver'],
    discretize_continuous=True,
    mode='classification'
)

# Generate explanations for each of the first five rows
lime_explanations = []
for i in range(5):
    explanation = explainer.explain_instance(first_five_rows.iloc[i].values, rf_model.predict_proba)
    lime_explanations.append(explanation)
    explanation.show_in_notebook()

# lime_explanations
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
lime_aggregated_data = pd.DataFrame()
for i in range(5):
  explanation = explainer.explain_instance(first_five_rows.iloc[i].values, rf_model.predict_proba)
  feture_importance = pd.DataFrame(explanation.as_list(), columns=['Feature', 'Importance'])
  lime_aggregated_data = pd.concat([lime_aggregated_data, feture_importance], ignore_index=True)

aggregated_explanations = lime_aggregated_data.groupby('Feature')['Importance'].sum().reset_index()
aggregated_explanations = aggregated_explanations.sort_values(by='Importance', ascending=False)
aggregated_explanations
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
#                    Feature  Importance
# ...
